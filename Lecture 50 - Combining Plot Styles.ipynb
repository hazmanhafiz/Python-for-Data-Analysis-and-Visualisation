# %%
# Let's begin by importing what we'll need (You'll probably be copying and pasting this a lot)

# The normal imports
import numpy as np
from numpy.random import randn
import pandas as pd

# Import the stats librayr from numpy
from scipy import stats

# These are the plotting modules adn libraries we'll use:
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# Command so that plots appear in the iPython Notebook
# %matplotlib inline

# %%
dataset=randn(100)
dataset
# Out:
# array([-0.40783663,  0.69241595, -0.19473896,  0.265286  , -0.04970466,
#         0.30699344, -0.66086229, -0.25127674,  0.52600574, -1.26709131,
#         0.04995839,  0.54368189, -1.27284724,  0.8182005 ,  0.17545022,
#         0.14172103, -1.23113367,  1.32609958,  1.00384484,  1.69709653,
#        -0.62006308, -0.67985856, -0.64590949, -0.04510592,  1.71012598,
#         1.45327027, -0.86314583, -1.3553137 , -0.11165255,  1.97730303,
#        -1.16112893, -0.22177041,  0.13455481, -0.68881755, -0.46557386,
#         0.45006319, -0.39909001, -0.75667041, -0.27990806,  0.31334226,
#        -1.5722612 , -0.39350209, -0.46325147,  0.37434101,  0.06295033,
#        -0.43188961,  0.85987942,  1.24649744,  1.23113568,  0.83430221,
#        -1.03006629,  1.71321618,  2.02065135, -0.98292103, -1.07815478,
#        -0.6232254 ,  1.8391782 ,  0.64965158, -0.62317945,  0.7119156 ,
#        -0.59335034,  0.56602822, -1.26642635,  1.86402445,  1.05310005,
#        -0.14114289,  0.5432264 , -0.5128562 ,  0.41684325,  1.12876411,
#         1.28606379,  0.15886554, -0.48370914, -0.73620673,  0.58904871,
#         0.23256535, -0.12497355,  1.9848839 , -0.77727721, -0.24828855,
#        -0.43472162,  0.63763357, -1.00188695,  0.10074247,  1.07713563,
#         0.51443506,  0.1098963 , -0.0039061 ,  1.55307621, -0.95729101,
#        -0.64380047,  0.82393051, -0.18844404, -0.62448994,  0.57895811,
#        -0.48594373,  0.9138305 ,  0.20743776,  0.11261567,  0.14295081])

# %%
sns.distplot(dataset,bins=25)

# %%
sns.distplot(dataset,bins=25,rug=True,hist=False)

# %%
#define each individual plot in the combined plot
sns.distplot(dataset,bins=25,
            kde_kws={'color':'red','label':'KDE PLOT'},
            hist_kws={'color':'blue','label':'HIST'})

# %%
from pandas import Series

ser1=Series(dataset,name='My Data')

ser1
# Out:
# 0     1.184178
# 1     0.482729
# 2     0.176783
# 3     0.310911
# 4     0.128760
# 5     1.703631
# 6    -0.124896
# 7    -1.070090
# 8     0.717134
# 9     0.373400
# 10   -0.092492
# 11   -0.238922
# 12    0.126213
# 13   -0.379461
# 14    0.734305
# 15    1.453649
# 16   -0.107800
# 17   -0.770348
# 18    0.337561
# 19   -0.345755
# 20    1.612042
# 21   -1.548311
# 22    1.518396
# 23    1.760974
# 24    0.227912
# 25    0.307853
# 26    1.412383
# 27   -0.289051
# 28   -0.385747
# 29   -0.619629
#         ...
# 70   -0.703550
# 71   -0.557748
# 72   -0.904175
# 73    1.535819
# 74    1.317403
# 75    0.266448
# 76    1.072530
# 77    0.159070
# 78   -0.485104
# 79    1.614648
# 80   -1.400040
# 81   -0.327871
# 82   -0.444711
# 83   -0.950997
# 84    0.155270
# 85   -0.522932
# 86   -1.103145
# 87   -0.684977
# 88    1.571170
# 89    0.878796
# 90   -0.038504
# 91    0.436662
# 92    2.337516
# 93    0.450695
# 94    0.299790
# 95    0.948821
# 96   -0.043682
# 97    0.813440
# 98    1.289493
# 99    0.564728
# Name: My Data, dtype: float64

# %%
sns.distplot(dataset,bins=25)
