# %%
import numpy as np
import pandas as pd
from pandas import Series,DataFrame

# %%
import webbrowser
website='https://en.wikipedia.org/wiki/NFL_win–loss_records'
webbrowser.open(website)
# Out:
# True

# %%
nfl_frame=pd.read_clipboard()

# %%
nfl_frame
# Out:
#    Rank     Team       Won      Lost  Tied  Pct.   First       NFL Season  \
# 0     1   Dallas   Cowboys       493   367     6   0.573  1960.000    866
# 1     2    Green       Bay   Packers   730   553  37.000     0.567   1921
# 2     3  Chicago     Bears       744   568    42   0.565  1920.000  1,354
# 3     4    Miami  Dolphins       439   341     4   0.563  1966.000    784
# 4     5      New   England  Patriots   476   383   9.000     0.554   1960
#
#    Total  Games Division
# 0    NFC   East      NaN
# 1  1,320    NFC    North
# 2    NFC  North      NaN
# 3    AFC   East      NaN
# 4    868    AFC     East

# %%
nfl_frame.columns
# Out:
# Index([u'Rank', u'Team', u'Won', u'Lost', u'Tied', u'Pct.', u'First', u'NFL',
#        u'Season', u'Total', u'Games', u'Division'],
#       dtype='object')

# %%
nfl_frame.Rank
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# Name: Rank, dtype: int64

# %%
nfl_frame.Lost
# Out:
# 0         493
# 1     Packers
# 2         744
# 3         439
# 4    Patriots
# Name: Lost, dtype: object

# %%
nfl_frame.Team
# Out:
# 0     Dallas
# 1      Green
# 2    Chicago
# 3      Miami
# 4        New
# Name: Team, dtype: object

# %%
nfl_frame['NFL']
# Out:
# 0    1960.000
# 1       0.567
# 2    1920.000
# 3    1966.000
# 4       0.554
# Name: NFL, dtype: float64

# %%
#create a new subset of dataframe
DataFrame(nfl_frame,columns=['Team','First NFL Season','Total Games'])
# Out:
#       Team  First NFL Season  Total Games
# 0   Dallas               NaN          NaN
# 1    Green               NaN          NaN
# 2  Chicago               NaN          NaN
# 3    Miami               NaN          NaN
# 4      New               NaN          NaN

# %%
nfl_frame
# Out:
#    Rank     Team       Won      Lost  Tied  Pct.   First       NFL Season  \
# 0     1   Dallas   Cowboys       493   367     6   0.573  1960.000    866
# 1     2    Green       Bay   Packers   730   553  37.000     0.567   1921
# 2     3  Chicago     Bears       744   568    42   0.565  1920.000  1,354
# 3     4    Miami  Dolphins       439   341     4   0.563  1966.000    784
# 4     5      New   England  Patriots   476   383   9.000     0.554   1960
#
#    Total  Games Division
# 0    NFC   East      NaN
# 1  1,320    NFC    North
# 2    NFC  North      NaN
# 3    AFC   East      NaN
# 4    868    AFC     East

# %%
nfl_frame.head()
# Out:
#    Rank     Team       Won      Lost  Tied  Pct.   First       NFL Season  \
# 0     1   Dallas   Cowboys       493   367     6   0.573  1960.000    866
# 1     2    Green       Bay   Packers   730   553  37.000     0.567   1921
# 2     3  Chicago     Bears       744   568    42   0.565  1920.000  1,354
# 3     4    Miami  Dolphins       439   341     4   0.563  1966.000    784
# 4     5      New   England  Patriots   476   383   9.000     0.554   1960
#
#    Total  Games Division
# 0    NFC   East      NaN
# 1  1,320    NFC    North
# 2    NFC  North      NaN
# 3    AFC   East      NaN
# 4    868    AFC     East

# %%
nfl_frame.head(3)
# Out:
#    Rank     Team      Won     Lost  Tied  Pct.   First       NFL Season  \
# 0     1   Dallas  Cowboys      493   367     6   0.573  1960.000    866
# 1     2    Green      Bay  Packers   730   553  37.000     0.567   1921
# 2     3  Chicago    Bears      744   568    42   0.565  1920.000  1,354
#
#    Total  Games Division
# 0    NFC   East      NaN
# 1  1,320    NFC    North
# 2    NFC  North      NaN

# %%
#show details of a particular index
nfl_frame.ix[3]
# Out:
# Rank               4
# Team           Miami
# Won         Dolphins
# Lost             439
# Tied             341
# Pct.               4
# First          0.563
# NFL             1966
# Season           784
# Total            AFC
# Games           East
# Division         NaN
# Name: 3, dtype: object

# %%
nfl_frame["Stadium"]="Levi's Stadium"
nfl_frame
# Out:
#    Rank     Team       Won      Lost  Tied  Pct.   First       NFL Season  \
# 0     1   Dallas   Cowboys       493   367     6   0.573  1960.000    866
# 1     2    Green       Bay   Packers   730   553  37.000     0.567   1921
# 2     3  Chicago     Bears       744   568    42   0.565  1920.000  1,354
# 3     4    Miami  Dolphins       439   341     4   0.563  1966.000    784
# 4     5      New   England  Patriots   476   383   9.000     0.554   1960
#
#    Total  Games Division         Stadium
# 0    NFC   East      NaN  Levi's Stadium
# 1  1,320    NFC    North  Levi's Stadium
# 2    NFC  North      NaN  Levi's Stadium
# 3    AFC   East      NaN  Levi's Stadium
# 4    868    AFC     East  Levi's Stadium

# %%
nfl_frame['Stadium']=np.arange(5)
nfl_frame
# Out:
#    Rank     Team       Won      Lost  Tied  Pct.   First       NFL Season  \
# 0     1   Dallas   Cowboys       493   367     6   0.573  1960.000    866
# 1     2    Green       Bay   Packers   730   553  37.000     0.567   1921
# 2     3  Chicago     Bears       744   568    42   0.565  1920.000  1,354
# 3     4    Miami  Dolphins       439   341     4   0.563  1966.000    784
# 4     5      New   England  Patriots   476   383   9.000     0.554   1960
#
#    Total  Games Division  Stadium
# 0    NFC   East      NaN        0
# 1  1,320    NFC    North        1
# 2    NFC  North      NaN        2
# 3    AFC   East      NaN        3
# 4    868    AFC     East        4

# %%
stadiums=Series(["Levi's Stadium","AT&T Stadium"],index=[0,4])
stadiums
# Out:
# 0    Levi's Stadium
# 4      AT&T Stadium
# dtype: object

# %%
nfl_frame['Stadium']=stadiums
nfl_frame
# Out:
#    Rank     Team       Won      Lost  Tied  Pct.   First       NFL Season  \
# 0     1   Dallas   Cowboys       493   367     6   0.573  1960.000    866
# 1     2    Green       Bay   Packers   730   553  37.000     0.567   1921
# 2     3  Chicago     Bears       744   568    42   0.565  1920.000  1,354
# 3     4    Miami  Dolphins       439   341     4   0.563  1966.000    784
# 4     5      New   England  Patriots   476   383   9.000     0.554   1960
#
#    Total  Games Division         Stadium
# 0    NFC   East      NaN  Levi's Stadium
# 1  1,320    NFC    North             NaN
# 2    NFC  North      NaN             NaN
# 3    AFC   East      NaN             NaN
# 4    868    AFC     East    AT&T Stadium

# %%
del nfl_frame['Stadium']
nfl_frame
# Out:
#    Rank     Team       Won      Lost  Tied  Pct.   First       NFL Season  \
# 0     1   Dallas   Cowboys       493   367     6   0.573  1960.000    866
# 1     2    Green       Bay   Packers   730   553  37.000     0.567   1921
# 2     3  Chicago     Bears       744   568    42   0.565  1920.000  1,354
# 3     4    Miami  Dolphins       439   341     4   0.563  1966.000    784
# 4     5      New   England  Patriots   476   383   9.000     0.554   1960
#
#    Total  Games Division
# 0    NFC   East      NaN
# 1  1,320    NFC    North
# 2    NFC  North      NaN
# 3    AFC   East      NaN
# 4    868    AFC     East

# %%
data = {'City':['SF','LA','NYC'],'Population':[837000,900000,3000000]}

# %%
city_frame=DataFrame(data)
city_frame
# Out:
#   City  Population
# 0   SF      837000
# 1   LA      900000
# 2  NYC     3000000

# %%
website='http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.html'
webbrowser.open(website)
# Out:
# True
